# %% [markdown]
# # 9 Cleaning Data with Pandas

# %% [markdown]
# ## Coming Clean About Dirty Data

# %%
import pandas as pd

# %%
df = pd.read_json(open('nobel_winners/nobel_winners2.json'))

# %%
df.country
# Out:
# 0        Austria
# 1        Austria
# 2
# 3
# 4        Austria
#          ...
# 321      Austria
# 322    Argentina
# 323    Argentina
# 324    Argentina
# 325    Argentina
# Name: country, Length: 326, dtype: object

# %%
df.country.unique()
# Out:
# array(['Austria', '', 'Australia', 'Germany', 'Guatemala', 'Greece',
#        'Hong Kong', 'Hungary', 'Ghana', 'France', 'Finland', 'Denmark',
#        'East Timor', 'Egypt', 'Czech Republic',
#        "China, People's Republic of", 'Colombia',
#        'Congo, Democratic Republic', 'Costa Rica', 'China, Republic of',
#        'Chile', 'Canada', 'Belgium', 'Bangladesh', 'Belarus', 'Argentina'],
#       dtype=object)

# %% [markdown]
# ## Inspecting the Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326 entries, 0 to 325
# Data columns (total 12 columns):
# link              326 non-null object
# name              326 non-null object
# year              326 non-null int64
# category          326 non-null object
# country           326 non-null object
# born_in           326 non-null object
# text              326 non-null object
# date_of_birth     321 non-null object
# date_of_death     240 non-null object
# place_of_birth    321 non-null object
# place_of_death    240 non-null object
# gender            321 non-null object
# dtypes: int64(1), object(11)
# memory usage: 30.7+ KB

# %%
df.describe()
# Out:
#               year
# count   326.000000
# mean   1960.012270
# std      38.490596
# min    1809.000000
# 25%    1927.000000
# 50%    1964.500000
# 75%    1993.750000
# max    2018.000000

# %%
# 9.1
df.describe(include=['object'])
# Out:
#                                              link               name  \
# count                                         326                326
# unique                                        309                321
# top     http://en.wikipedia.org/wiki/John_Polanyi  Vladimir Prelog *
# freq                                            3                  2
#
#                       category  country born_in  \
# count                      326      326     326
# unique                       6       26      18
# top     Physiology or Medicine  Germany
# freq                        78       83     261
#
#                                                      text    date_of_birth  \
# count                                                 326              321
# unique                                                322              301
# top     Vladimir Prelog *,  Ethnic Croat and national ...  23 January 1929
# freq                                                    2                3
#
#        date_of_death place_of_birth place_of_death gender
# count            240            321            240    321
# unique           227            212            139      2
# top     12 June 1982          Paris          Paris   male
# freq               2             22             19    302

# %%
# 9.2
df.head()
# Out:
#                                             link              name  year  \
# 0  http://en.wikipedia.org/wiki/Karl_Landsteiner  Karl Landsteiner  1930
# 1  http://en.wikipedia.org/wiki/Elfriede_Jelinek  Elfriede Jelinek  2004
# 2       http://en.wikipedia.org/wiki/Eric_Kandel     Eric Kandel *  2000
# 3       http://en.wikipedia.org/wiki/Walter_Kohn     Walter Kohn *  1998
# 4   http://en.wikipedia.org/wiki/Friedrich_Hayek   Friedrich Hayek  1974
#
#                  category  country  born_in  \
# 0  Physiology or Medicine  Austria
# 1              Literature  Austria
# 2  Physiology or Medicine           Austria
# 3               Chemistry           Austria
# 4               Economics  Austria
#
#                                               text    date_of_birth  \
# 0  Karl Landsteiner , Physiology or Medicine, 1930     14 June 1868
# 1              Elfriede Jelinek , Literature, 2004  20 October 1946
# 2      Eric Kandel *, Physiology or Medicine, 2000  7 November 1929
# 3                   Walter Kohn *, Chemistry, 1998     9 March 1923
# 4                Friedrich Hayek , Economics, 1974       8 May 1899
#
#    date_of_death place_of_birth        place_of_death  gender
# 0   26 June 1943         Vienna         New York City    male
# 1            NaN   Mürzzuschlag                   NaN  female
# 2            NaN         Vienna                   NaN    male
# 3  19 April 2016         Vienna         Santa Barbara    male
# 4  23 March 1992         Vienna  Freiburg im Breisgau    male

# %% [markdown]
# ## Indices and Pandas Data Selection

# %%
df.columns
# Out:
# Index(['link', 'name', 'year', 'category', 'country', 'born_in', 'text',
#        'date_of_birth', 'date_of_death', 'place_of_birth', 'place_of_death',
#        'gender'],
#       dtype='object')

# %%
df_name = df.set_index('name')

# %%
df_name.head(2)
# Out:
#                                                            link  year  \
# name
# Karl Landsteiner  http://en.wikipedia.org/wiki/Karl_Landsteiner  1930
# Elfriede Jelinek  http://en.wikipedia.org/wiki/Elfriede_Jelinek  2004
#
#                                 category  country born_in  \
# name
# Karl Landsteiner  Physiology or Medicine  Austria
# Elfriede Jelinek              Literature  Austria
#
#                                                              text  \
# name
# Karl Landsteiner  Karl Landsteiner , Physiology or Medicine, 1930
# Elfriede Jelinek              Elfriede Jelinek , Literature, 2004
#
#                     date_of_birth date_of_death place_of_birth place_of_death  \
# name
# Karl Landsteiner     14 June 1868  26 June 1943         Vienna  New York City
# Elfriede Jelinek  20 October 1946           NaN   Mürzzuschlag            NaN
#
#                   gender
# name
# Karl Landsteiner    male
# Elfriede Jelinek  female

# %%
df_name.reset_index(inplace=True)

# %%
df.head(2)
# Out:
#                                             link              name  year  \
# 0  http://en.wikipedia.org/wiki/Karl_Landsteiner  Karl Landsteiner  1930
# 1  http://en.wikipedia.org/wiki/Elfriede_Jelinek  Elfriede Jelinek  2004
#
#                  category  country born_in  \
# 0  Physiology or Medicine  Austria
# 1              Literature  Austria
#
#                                               text    date_of_birth  \
# 0  Karl Landsteiner , Physiology or Medicine, 1930     14 June 1868
# 1              Elfriede Jelinek , Literature, 2004  20 October 1946
#
#   date_of_death place_of_birth place_of_death  gender
# 0  26 June 1943         Vienna  New York City    male
# 1           NaN   Mürzzuschlag            NaN  female

# %%
bi_col = df.born_in
bi_col
# Out:
# 0
# 1
# 2      Austria
# 3      Austria
# 4
#         ...
# 321
# 322
# 323
# 324
# 325
# Name: born_in, Length: 326, dtype: object

# %%
type(bi_col)
# Out:
# pandas.core.series.Series

# %%
df.iloc[0]
# Out:
# link                http://en.wikipedia.org/wiki/Karl_Landsteiner
# name                                             Karl Landsteiner
# year                                                         1930
# category                                   Physiology or Medicine
# country                                                   Austria
# born_in
# text              Karl Landsteiner , Physiology or Medicine, 1930
# date_of_birth                                        14 June 1868
# date_of_death                                        26 June 1943
# place_of_birth                                             Vienna
# place_of_death                                      New York City
# gender                                                       male
# Name: 0, dtype: object

# %% [markdown]
# ### Selecting Multiple Rows

# %%
df[0:10]
# Out:
#                                                 link  \
# 0      http://en.wikipedia.org/wiki/Karl_Landsteiner
# 1      http://en.wikipedia.org/wiki/Elfriede_Jelinek
# 2           http://en.wikipedia.org/wiki/Eric_Kandel
# 3           http://en.wikipedia.org/wiki/Walter_Kohn
# 4       http://en.wikipedia.org/wiki/Friedrich_Hayek
# 5        http://en.wikipedia.org/wiki/John_Cornforth
# 6         http://en.wikipedia.org/wiki/Patrick_White
# 7  http://en.wikipedia.org/wiki/John_Eccles_(neur...
# 8  http://en.wikipedia.org/wiki/Frank_Macfarlane_...
# 9      http://en.wikipedia.org/wiki/Gerhard_Herzberg
#
#                           name  year                category    country  \
# 0             Karl Landsteiner  1930  Physiology or Medicine    Austria
# 1             Elfriede Jelinek  2004              Literature    Austria
# 2                Eric Kandel *  2000  Physiology or Medicine
# 3                Walter Kohn *  1998               Chemistry
# 4              Friedrich Hayek  1974               Economics    Austria
# 5             John Cornforth *  1975               Chemistry
# 6                Patrick White  1973              Literature  Australia
# 7            John Carew Eccles  1963  Physiology or Medicine  Australia
# 8  Sir Frank Macfarlane Burnet  1960  Physiology or Medicine  Australia
# 9           Gerhard Herzberg *  1971               Chemistry
#
#      born_in                                               text  \
# 0               Karl Landsteiner , Physiology or Medicine, 1930
# 1                           Elfriede Jelinek , Literature, 2004
# 2    Austria        Eric Kandel *, Physiology or Medicine, 2000
# 3    Austria                     Walter Kohn *, Chemistry, 1998
# 4                             Friedrich Hayek , Economics, 1974
# 5  Australia                  John Cornforth *, Chemistry, 1975
# 6             Patrick White ,  born in the United Kingdom , ...
# 7              John Carew Eccles , Physiology or Medicine, 1963
# 8             Sir Frank Macfarlane Burnet , Physiology or Me...
# 9    Germany                Gerhard Herzberg *, Chemistry, 1971
#
#       date_of_birth      date_of_death place_of_birth        place_of_death  \
# 0      14 June 1868       26 June 1943         Vienna         New York City
# 1   20 October 1946                NaN   Mürzzuschlag                   NaN
# 2   7 November 1929                NaN         Vienna                   NaN
# 3      9 March 1923      19 April 2016         Vienna         Santa Barbara
# 4        8 May 1899      23 March 1992         Vienna  Freiburg im Breisgau
# 5  7 September 1917    8 December 2013         Sydney              Brighton
# 6       28 May 1912  30 September 1990         London                Sydney
# 7   27 January 1903         2 May 1997      Melbourne               Locarno
# 8  3 September 1899     31 August 1985      Traralgon             Melbourne
# 9  25 December 1904       3 March 1999        Hamburg                Ottawa
#
#    gender
# 0    male
# 1  female
# 2    male
# 3    male
# 4    male
# 5    male
# 6    male
# 7    male
# 8    male
# 9    male

# %%
df[-4:]
# Out:
#                                                   link                   name  \
# 322  http://en.wikipedia.org/wiki/Adolfo_P%C3%A9rez...  Adolfo Pérez Esquivel
# 323  http://en.wikipedia.org/wiki/Luis_Federico_Leloir   Luis Federico Leloir
# 324      http://en.wikipedia.org/wiki/Bernardo_Houssay       Bernardo Houssay
# 325  http://en.wikipedia.org/wiki/Carlos_Saavedra_L...  Carlos Saavedra Lamas
#
#      year                category    country born_in  \
# 322  1980                   Peace  Argentina
# 323  1970               Chemistry  Argentina
# 324  1947  Physiology or Medicine  Argentina
# 325  1936                   Peace  Argentina
#
#                                                 text     date_of_birth  \
# 322              Adolfo Pérez Esquivel , Peace, 1980  26 November 1931
# 323           Luis Federico Leloir , Chemistry, 1970  6 September 1906
# 324  Bernardo Houssay , Physiology or Medicine, 1947     10 April 1887
# 325              Carlos Saavedra Lamas , Peace, 1936   1 November 1878
#
#          date_of_death place_of_birth      place_of_death gender
# 322                NaN   Buenos Aires                 NaN   male
# 323    2 December 1987          Paris  Catamarca Province   male
# 324  21 September 1971   Buenos Aires        Buenos Aires   male
# 325         5 May 1959   Buenos Aires        Buenos Aires   male

# %%
mask = df.year > 2000
mask
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 321    False
# 322    False
# 323    False
# 324    False
# 325    False
# Name: year, Length: 326, dtype: bool

# %%
winners_since_2000 = df[mask]
winners_since_2000.count()
# Out:
# link              53
# name              53
# year              53
# category          53
# country           53
# born_in           53
# text              53
# date_of_birth     51
# date_of_death     10
# place_of_birth    51
# place_of_death    10
# gender            51
# dtype: int64

# %%
winners_since_2000 = df[df.year > 2000]

# %% [markdown]
# ## Cleaning the Data

# %%
df.born_in.describe()
# Out:
# count     326
# unique     18
# top
# freq      261
# Name: born_in, dtype: object

# %% [markdown]
# ### Finding Mixed Types

# %%
set(df.born_in.apply(type))
# Out:
# {str}

# %% [markdown]
# ### Replacing Strings

# %%
import numpy as np

# %%
bio_col = df.born_in

# %%
bio_col.replace('', np.nan, inplace=True)
bio_col
# Out:
# 0          NaN
# 1          NaN
# 2      Austria
# 3      Austria
# 4          NaN
#         ...
# 321        NaN
# 322        NaN
# 323        NaN
# 324        NaN
# 325        NaN
# Name: born_in, Length: 326, dtype: object

# %%
bio_col.count()
# Out:
# 65

# %%
df.replace('', np.nan, inplace=True)
df.head()
# Out:
#                                             link              name  year  \
# 0  http://en.wikipedia.org/wiki/Karl_Landsteiner  Karl Landsteiner  1930
# 1  http://en.wikipedia.org/wiki/Elfriede_Jelinek  Elfriede Jelinek  2004
# 2       http://en.wikipedia.org/wiki/Eric_Kandel     Eric Kandel *  2000
# 3       http://en.wikipedia.org/wiki/Walter_Kohn     Walter Kohn *  1998
# 4   http://en.wikipedia.org/wiki/Friedrich_Hayek   Friedrich Hayek  1974
#
#                  category  country  born_in  \
# 0  Physiology or Medicine  Austria      NaN
# 1              Literature  Austria      NaN
# 2  Physiology or Medicine      NaN  Austria
# 3               Chemistry      NaN  Austria
# 4               Economics  Austria      NaN
#
#                                               text    date_of_birth  \
# 0  Karl Landsteiner , Physiology or Medicine, 1930     14 June 1868
# 1              Elfriede Jelinek , Literature, 2004  20 October 1946
# 2      Eric Kandel *, Physiology or Medicine, 2000  7 November 1929
# 3                   Walter Kohn *, Chemistry, 1998     9 March 1923
# 4                Friedrich Hayek , Economics, 1974       8 May 1899
#
#    date_of_death place_of_birth        place_of_death  gender
# 0   26 June 1943         Vienna         New York City    male
# 1            NaN   Mürzzuschlag                   NaN  female
# 2            NaN         Vienna                   NaN    male
# 3  19 April 2016         Vienna         Santa Barbara    male
# 4  23 March 1992         Vienna  Freiburg im Breisgau    male

# %%
df[df.name.str.contains('\*')]['name']
# Out:
# 2              Eric Kandel *
# 3              Walter Kohn *
# 5           John Cornforth *
# 9         Gerhard Herzberg *
# 11            Bernard Katz *
#                ...
# 306             Ivo Andrić *
# 307        Vladimir Prelog *
# 308          Peter Medawar *
# 309          Elias Canetti *
# 315    Elizabeth Blackburn *
# Name: name, Length: 65, dtype: object

# %%
df.name = df.name.str.replace('*', '')
df.name = df.name.str.strip()

# %%
df[df.name.str.contains('\*')]
# Out:
# Empty DataFrame
# Columns: [link, name, year, category, country, born_in, text, date_of_birth, date_of_death, place_of_birth, place_of_death, gender]
# Index: []

# %% [markdown]
# ### Removing Rows

# %%
np.nan == np.nan
# Out:
# False

# %%
df[df.born_in.notnull()]
# Out:
#                                                  link                 name  \
# 2            http://en.wikipedia.org/wiki/Eric_Kandel          Eric Kandel
# 3            http://en.wikipedia.org/wiki/Walter_Kohn          Walter Kohn
# 5         http://en.wikipedia.org/wiki/John_Cornforth       John Cornforth
# 9       http://en.wikipedia.org/wiki/Gerhard_Herzberg     Gerhard Herzberg
# 11          http://en.wikipedia.org/wiki/Bernard_Katz         Bernard Katz
# ..                                                ...                  ...
# 306      http://en.wikipedia.org/wiki/Ivo_Andri%C4%87           Ivo Andrić
# 307      http://en.wikipedia.org/wiki/Vladimir_Prelog      Vladimir Prelog
# 308        http://en.wikipedia.org/wiki/Peter_Medawar        Peter Medawar
# 309        http://en.wikipedia.org/wiki/Elias_Canetti        Elias Canetti
# 315  http://en.wikipedia.org/wiki/Elizabeth_Blackburn  Elizabeth Blackburn
#
#      year                category country                 born_in  \
# 2    2000  Physiology or Medicine     NaN                 Austria
# 3    1998               Chemistry     NaN                 Austria
# 5    1975               Chemistry     NaN               Australia
# 9    1971               Chemistry     NaN                 Germany
# 11   1970  Physiology or Medicine     NaN                 Germany
# ..    ...                     ...     ...                     ...
# 306  1961              Literature     NaN  Bosnia and Herzegovina
# 307  1975               Chemistry     NaN  Bosnia and Herzegovina
# 308  1960  Physiology or Medicine     NaN                  Brazil
# 309  1981              Literature     NaN                Bulgaria
# 315  2009  Physiology or Medicine     NaN               Australia
#
#                                                   text     date_of_birth  \
# 2          Eric Kandel *, Physiology or Medicine, 2000   7 November 1929
# 3                       Walter Kohn *, Chemistry, 1998      9 March 1923
# 5                    John Cornforth *, Chemistry, 1975  7 September 1917
# 9                  Gerhard Herzberg *, Chemistry, 1971  25 December 1904
# 11        Bernard Katz *, Physiology or Medicine, 1970     26 March 1911
# ..                                                 ...               ...
# 306  Ivo Andrić *,  Ethnic Croat and national  born...    9 October 1892
# 307  Vladimir Prelog *,  Ethnic Croat and national ...      23 July 1906
# 308      Peter Medawar *, Physiology or Medicine, 1960  28 February 1915
# 309                  Elias Canetti *, Literature, 1981      25 July 1905
# 315  Elizabeth Blackburn *, Physiology or Medicine,...  26 November 1948
#
#        date_of_death  place_of_birth place_of_death  gender
# 2                NaN          Vienna            NaN    male
# 3      19 April 2016          Vienna  Santa Barbara    male
# 5    8 December 2013          Sydney       Brighton    male
# 9       3 March 1999         Hamburg         Ottawa    male
# 11     20 April 2003         Leipzig         London    male
# ..               ...             ...            ...     ...
# 306    13 March 1975           Dolac       Belgrade    male
# 307   7 January 1998        Sarajevo         Zürich    male
# 308   2 October 1987  Rio de Janeiro         London    male
# 309   14 August 1994            Ruse         Zürich    male
# 315              NaN          Hobart            NaN  female
#
# [65 rows x 12 columns]

# %% [markdown]
# ### Finding Duplicates

# %%
dupes_by_name = df[df.duplicated('name')]
dupes_by_name.count()
# Out:
# link              17
# name              17
# year              17
# category          17
# country            9
# born_in            8
# text              17
# date_of_birth     17
# date_of_death     13
# place_of_birth    17
# place_of_death    13
# gender            17
# dtype: int64

# %%
all_dupes = df[df.duplicated('name') | df.duplicated('name', keep='last')]
all_dupes.count()
# Out:
# link              33
# name              33
# year              33
# category          33
# country           17
# born_in           16
# text              33
# date_of_birth     33
# date_of_death     26
# place_of_birth    33
# place_of_death    26
# gender            33
# dtype: int64

# %%
all_dupes = df[df.name.isin(dupes_by_name.name)]
all_dupes.count()
# Out:
# link              33
# name              33
# year              33
# category          33
# country           17
# born_in           16
# text              33
# date_of_birth     33
# date_of_death     26
# place_of_birth    33
# place_of_death    26
# gender            33
# dtype: int64

# %%
for name, rows in df.groupby('name'):
    print(f'name: {name}, number of rows: {len(rows)}')
# Out:
# name: Aage Bohr, number of rows: 1
# name: Adolf Butenandt, number of rows: 1
# name: Adolf Otto Reinhold Windaus, number of rows: 1
# name: Adolf von Baeyer, number of rows: 1
# name: Adolfo Pérez Esquivel, number of rows: 1
# name: Ahmed Zewail, number of rows: 1
# name: Albert Camus, number of rows: 1
# name: Albert Claude, number of rows: 1
# name: Albert Einstein, number of rows: 1
# name: Albert Fert, number of rows: 1
# name: Albert Schweitzer, number of rows: 2
# name: Albert Szent-Györgyi, number of rows: 1
# name: Albrecht Kossel, number of rows: 1
# name: Alexis Carrel, number of rows: 1
# name: Alfred Hermann Fried, number of rows: 1
# name: Alfred Kastler, number of rows: 1
# name: Alfred Werner, number of rows: 1
# name: Alice Munro, number of rows: 1
# name: Anatole France, number of rows: 1
# name: André Frédéric Cournand, number of rows: 1
# name: André Gide, number of rows: 1
# name: André Lwoff, number of rows: 1
# name: Antoine Henri Becquerel, number of rows: 1
# name: Anwar Sadat, number of rows: 1
# name: Aristide Briand, number of rows: 1
# name: Arno Penzias, number of rows: 1
# name: Arthur B. McDonald, number of rows: 1
# name: Artturi Ilmari Virtanen, number of rows: 1
# name: August Krogh, number of rows: 1
# name: Auguste Beernaert, number of rows: 1
# name: Avram Hershko, number of rows: 1
# name: Barry Marshall, number of rows: 1
# name: Ben Roy Mottelson, number of rows: 1
# name: Bengt R. Holmström, number of rows: 1
# name: Bernard Katz, number of rows: 1
# name: Bernardo Houssay, number of rows: 1
# name: Bert Sakmann, number of rows: 1
# name: Bertha von Suttner, number of rows: 2
# name: Bertram Brockhouse, number of rows: 1
# name: Brian Schmidt, number of rows: 1
# name: Carl Bosch, number of rows: 1
# name: Carl Ferdinand Cori, number of rows: 1
# name: Carl von Ossietzky, number of rows: 1
# name: Carlos Filipe Ximenes Belo, number of rows: 1
# name: Carlos Saavedra Lamas, number of rows: 1
# name: Charles B. Huggins, number of rows: 1
# name: Charles K. Kao, number of rows: 2
# name: Charles Louis Alphonse Laveran, number of rows: 1
# name: Charles Nicolle, number of rows: 1
# name: Charles Richet, number of rows: 1
# name: Chen-Ning Yang, number of rows: 1
# name: Christian de Duve, number of rows: 1
# name: Christiane Nüsslein-Volhard, number of rows: 1
# name: Christopher A. Pissarides, number of rows: 1
# name: Claude Cohen-Tannoudji, number of rows: 1
# name: Claude Simon, number of rows: 1
# name: Corneille Heymans, number of rows: 1
# name: César Milstein, number of rows: 1
# name: Daniel C. Tsui, number of rows: 2
# name: David H. Hubel, number of rows: 1
# name: Denis Mukwege, number of rows: 1
# name: Dennis Gabor, number of rows: 1
# name: Dominique Pire, number of rows: 1
# name: Donna Strickland, number of rows: 1
# name: Eduard Buchner, number of rows: 1
# name: Elfriede Jelinek, number of rows: 1
# name: Elias Canetti, number of rows: 1
# name: Elizabeth Blackburn, number of rows: 1
# name: Emil Adolf von Behring, number of rows: 1
# name: Eric Kandel, number of rows: 1
# name: Ernest Rutherford, number of rows: 1
# name: Ernst Boris Chain, number of rows: 1
# name: Ernst Otto Fischer, number of rows: 1
# name: Ernst Ruska, number of rows: 1
# name: Erwin Neher, number of rows: 1
# name: Erwin Schrödinger, number of rows: 1
# name: Eugene Wigner, number of rows: 1
# name: Feodor Felix Konrad Lynen, number of rows: 1
# name: Ferdinand Buisson, number of rows: 1
# name: Frans Eemil Sillanpää, number of rows: 1
# name: François Englert, number of rows: 1
# name: François Jacob, number of rows: 1
# name: François Mauriac, number of rows: 1
# name: Françoise Barré-Sinoussi, number of rows: 1
# name: Frederick G. Banting, number of rows: 1
# name: Fredrik Bajer, number of rows: 1
# name: Friedrich Bergius, number of rows: 1
# name: Friedrich Hayek, number of rows: 1
# name: Fritz Albert Lipmann, number of rows: 1
# name: Fritz Haber, number of rows: 1
# name: Fritz Pregl, number of rows: 1
# name: Frédéric Joliot-Curie, number of rows: 1
# name: Frédéric Mistral, number of rows: 1
# name: Frédéric Passy, number of rows: 1
# name: Gabriel García Márquez, number of rows: 1
# name: Gabriel Lippmann, number of rows: 1
# name: Gabriela Mistral, number of rows: 1
# name: Gao Xingjian, number of rows: 2
# name: Georg Wittig, number of rows: 1
# name: Georg von Békésy, number of rows: 1
# name: George Andrew Olah, number of rows: 1
# name: George de Hevesy, number of rows: 1
# name: Georges Charpak, number of rows: 1
# name: Georges J.F. Köhler, number of rows: 1
# name: Gerd Binnig, number of rows: 1
# name: Gerhard Domagk, number of rows: 1
# name: Gerhard Ertl, number of rows: 1
# name: Gerhard Herzberg, number of rows: 2
# name: Gerhart Hauptmann, number of rows: 1
# name: Gerty Cori, number of rows: 1
# name: Giorgos Seferis, number of rows: 1
# name: Grameen Bank, number of rows: 1
# name: Gustav Ludwig Hertz, number of rows: 1
# name: Gustav Stresemann, number of rows: 1
# name: Gérard Debreu, number of rows: 1
# name: Gérard Mourou, number of rows: 1
# name: Günter Blobel, number of rows: 1
# name: Günter Grass, number of rows: 1
# name: Hans Adolf Krebs, number of rows: 1
# name: Hans Bethe, number of rows: 1
# name: Hans Fischer, number of rows: 1
# name: Hans G. Dehmelt, number of rows: 1
# name: Hans Spemann, number of rows: 1
# name: Hans von Euler-Chelpin, number of rows: 1
# name: Harald zur Hausen, number of rows: 1
# name: Hartmut Michel, number of rows: 1
# name: Heinrich Böll, number of rows: 1
# name: Heinrich Otto Wieland, number of rows: 1
# name: Henri Bergson, number of rows: 1
# name: Henri La Fontaine, number of rows: 1
# name: Henri Moissan, number of rows: 1
# name: Henrik Dam, number of rows: 1
# name: Henrik Pontoppidan, number of rows: 1
# name: Henry Dunant, number of rows: 1
# name: Henry Kissinger, number of rows: 1
# name: Henry Taube, number of rows: 1
# name: Herbert Kroemer, number of rows: 1
# name: Hermann Emil Fischer, number of rows: 1
# name: Hermann Hesse, number of rows: 1
# name: Hermann Staudinger, number of rows: 1
# name: Herta Müller, number of rows: 1
# name: Horst L. Störmer, number of rows: 1
# name: Howard Florey, number of rows: 1
# name: Ilya Prigogine, number of rows: 1
# name: Imre Kertész, number of rows: 1
# name: Institut de Droit International, number of rows: 1
# name: International Atomic Energy Agency, number of rows: 1
# name: Irène Joliot-Curie, number of rows: 1
# name: Ivan Bunin, number of rows: 1
# name: Ivo Andrić, number of rows: 1
# name: J. Georg Bednorz, number of rows: 1
# name: J. Hans D. Jensen, number of rows: 1
# name: J. M. G. Le Clézio, number of rows: 1
# name: J. Robin Warren, number of rows: 1
# name: Jack Steinberger, number of rows: 1
# name: Jack W. Szostak, number of rows: 1
# name: Jacques Monod, number of rows: 1
# name: James Franck, number of rows: 1
# name: Jaroslav Heyrovský, number of rows: 1
# name: Jaroslav Seifert, number of rows: 1
# name: Jean Baptiste Perrin, number of rows: 1
# name: Jean Dausset, number of rows: 1
# name: Jean Tirole, number of rows: 1
# name: Jean-Marie Lehn, number of rows: 1
# name: Jean-Paul Sartre, number of rows: 1
# name: Jean-Pierre Sauvage, number of rows: 1
# name: Jens Christian Skou, number of rows: 1
# name: Joachim Frank, number of rows: 1
# name: Johann Deisenhofer, number of rows: 1
# name: Johannes Fibiger, number of rows: 1
# name: Johannes Stark, number of rows: 1
# name: Johannes V. Jensen, number of rows: 1
# name: John Carew Eccles, number of rows: 1
# name: John Cornforth, number of rows: 1
# name: John Harsanyi, number of rows: 1
# name: John James Rickard Macleod, number of rows: 1
# name: John Polanyi, number of rows: 3
# name: José Ramos-Horta, number of rows: 1
# name: Juan Manuel Santos Calderón, number of rows: 1
# name: Jules A. Hoffmann, number of rows: 1
# name: Jules Bordet, number of rows: 1
# name: Julius Wagner-Jauregg, number of rows: 1
# name: Karl Adolph Gjellerup, number of rows: 1
# name: Karl Ferdinand Braun, number of rows: 1
# name: Karl Landsteiner, number of rows: 1
# name: Karl Ziegler, number of rows: 1
# name: Karl von Frisch, number of rows: 2
# name: Klaus von Klitzing, number of rows: 1
# name: Kofi Annan, number of rows: 1
# name: Konrad Bloch, number of rows: 1
# name: Konrad Lorenz, number of rows: 1
# name: Kurt Alder, number of rows: 1
# name: Leopold Ružička, number of rows: 1
# name: Lester B. Pearson, number of rows: 1
# name: Liu Xiaobo, number of rows: 1
# name: Louis Néel, number of rows: 1
# name: Louis Renault, number of rows: 1
# name: Louis de Broglie, number of rows: 1
# name: Luc Montagnier, number of rows: 1
# name: Ludwig Quidde, number of rows: 1
# name: Luis Federico Leloir, number of rows: 2
# name: Léon Bourgeois, number of rows: 1
# name: Léon Jouhaux, number of rows: 1
# name: Manfred Eigen, number of rows: 1
# name: Maria Goeppert-Mayer, number of rows: 1
# name: Marie Curie, number of rows: 2
# name: Martin Karplus, number of rows: 1
# name: Martti Ahtisaari, number of rows: 1
# name: Maurice Allais, number of rows: 1
# name: Maurice Maeterlinck, number of rows: 1
# name: Max Born, number of rows: 1
# name: Max Delbrück, number of rows: 1
# name: Max Karl Ernst Ludwig Planck, number of rows: 1
# name: Max Perutz, number of rows: 1
# name: Max von Laue, number of rows: 1
# name: Michael Smith, number of rows: 1
# name: Miguel Ángel Asturias, number of rows: 1
# name: Mo Yan, number of rows: 1
# name: Mohamed ElBaradei, number of rows: 1
# name: Muhammad Yunus, number of rows: 1
# name: Myron Scholes, number of rows: 1
# name: Médecins Sans Frontières, number of rows: 1
# name: Naguib Mahfouz, number of rows: 1
# name: Nelly Sachs, number of rows: 1
# name: Niels Bohr, number of rows: 1
# name: Niels Kaj Jerne, number of rows: 1
# name: Niels Ryberg Finsen, number of rows: 2
# name: Odysseas Elytis, number of rows: 1
# name: Otto Diels, number of rows: 1
# name: Otto Fritz Meyerhof, number of rows: 1
# name: Otto Hahn, number of rows: 1
# name: Otto Heinrich Warburg, number of rows: 1
# name: Otto Loewi, number of rows: 2
# name: Otto Stern, number of rows: 1
# name: Otto Wallach, number of rows: 1
# name: Pablo Neruda, number of rows: 1
# name: Patrick Modiano, number of rows: 1
# name: Patrick White, number of rows: 1
# name: Paul Ehrlich, number of rows: 1
# name: Paul J. Crutzen, number of rows: 1
# name: Paul Johann Ludwig Heyse, number of rows: 1
# name: Paul Sabatier, number of rows: 1
# name: Paul-Henri-Benjamin d'Estournelles de Constant, number of rows: 1
# name: Peter C. Doherty, number of rows: 1
# name: Peter Grünberg, number of rows: 2
# name: Peter Medawar, number of rows: 1
# name: Philipp Lenard, number of rows: 1
# name: Pierre Curie, number of rows: 1
# name: Pierre-Gilles de Gennes, number of rows: 1
# name: Polykarp Kusch, number of rows: 1
# name: Pugwash Conferences on Science and World Affairs, number of rows: 1
# name: Ragnar Granit, number of rows: 1
# name: Rainer Weiss, number of rows: 1
# name: Ralph M. Steinman, number of rows: 1
# name: Reinhard Selten, number of rows: 1
# name: René Cassin, number of rows: 1
# name: Richard Adolf Zsigmondy, number of rows: 2
# name: Richard E. Taylor, number of rows: 1
# name: Richard Kuhn, number of rows: 2
# name: Richard Willstätter, number of rows: 1
# name: Rigoberta Menchú, number of rows: 1
# name: Robert Huber, number of rows: 1
# name: Robert Koch, number of rows: 1
# name: Robert Mundell, number of rows: 1
# name: Roger Guillemin, number of rows: 1
# name: Roger Martin du Gard, number of rows: 1
# name: Rolf Zinkernagel, number of rows: 1
# name: Romain Rolland, number of rows: 1
# name: Rudolf Christoph Eucken, number of rows: 1
# name: Rudolf Mössbauer, number of rows: 1
# name: Rudolph A. Marcus, number of rows: 1
# name: Róbert Bárány, number of rows: 1
# name: Saint-John Perse, number of rows: 1
# name: Saul Bellow, number of rows: 1
# name: Serge Haroche, number of rows: 1
# name: Seán MacBride, number of rows: 1
# name: Sidney Altman, number of rows: 1
# name: Sir Frank Macfarlane Burnet, number of rows: 1
# name: Stefan Hell, number of rows: 1
# name: Sully Prudhomme, number of rows: 1
# name: Svetlana Alexievich, number of rows: 1
# name: Theodor Mommsen, number of rows: 1
# name: Theodor W. Hänsch, number of rows: 1
# name: Thomas C. Südhof, number of rows: 1
# name: Thomas Mann, number of rows: 1
# name: Tsung-Dao Lee, number of rows: 1
# name: Tu Youyou, number of rows: 1
# name: Victor Francis Hess, number of rows: 1
# name: Victor Grignard, number of rows: 1
# name: Vladimir Prelog, number of rows: 2
# name: Walter Kohn, number of rows: 1
# name: Walther Bothe, number of rows: 1
# name: Walther Nernst, number of rows: 1
# name: Werner Forssmann, number of rows: 1
# name: Werner Karl Heisenberg, number of rows: 1
# name: Wilhelm Conrad Röntgen, number of rows: 1
# name: Wilhelm Ostwald, number of rows: 1
# name: Wilhelm Wien, number of rows: 1
# name: Willard S. Boyle, number of rows: 1
# name: William Giauque, number of rows: 1
# name: William Lawrence Bragg, number of rows: 1
# name: William Vickrey, number of rows: 1
# name: Willy Brandt, number of rows: 1
# name: Wolfgang Ketterle, number of rows: 1
# name: Wolfgang Paul, number of rows: 1
# name: Wolfgang Pauli, number of rows: 1
# name: Yves Chauvin, number of rows: 1
# name: Zhores Alferov, number of rows: 1
# name: Óscar Arias Sánchez, number of rows: 1

# %%
pd.concat([g for _, g in df.groupby('name') if len(g) > 1])['name']
# Out:
# 64           Albert Schweitzer
# 185          Albert Schweitzer
# 231         Bertha von Suttner
# 321         Bertha von Suttner
# 21              Charles K. Kao
# 267             Charles K. Kao
# 253             Daniel C. Tsui
# 286             Daniel C. Tsui
# 203               Gao Xingjian
# 252               Gao Xingjian
# 9             Gerhard Herzberg
# 279           Gerhard Herzberg
# 48                John Polanyi
# 101               John Polanyi
# 275               John Polanyi
# 110            Karl von Frisch
# 167            Karl von Frisch
# 189       Luis Federico Leloir
# 323       Luis Federico Leloir
# 143                Marie Curie
# 160                Marie Curie
# 217        Niels Ryberg Finsen
# 228        Niels Ryberg Finsen
# 74                  Otto Loewi
# 192                 Otto Loewi
# 124             Peter Grünberg
# 247             Peter Grünberg
# 54     Richard Adolf Zsigmondy
# 245    Richard Adolf Zsigmondy
# 73                Richard Kuhn
# 191               Richard Kuhn
# 259            Vladimir Prelog
# 307            Vladimir Prelog
# Name: name, dtype: object

# %% [markdown]
# ### Sorting Data

# %%
df2 = pd.DataFrame({
    'name': ['zak', 'alice', 'bob', 'mike', 'bob', 'bob'],
    'score': [4, 3, 5, 2, 3, 7]
})

df2.sort_values(['name', 'score'], ascending=[1, 0])
# Out:
#     name  score
# 1  alice      3
# 5    bob      7
# 2    bob      5
# 4    bob      3
# 3   mike      2
# 0    zak      4

# %%
all_dupes.sort_values('name')[['name', 'country', 'year']]
# Out:
#                         name    country  year
# 64         Albert Schweitzer        NaN  1952
# 185        Albert Schweitzer     France  1952
# 321       Bertha von Suttner    Austria  1905
# 231       Bertha von Suttner        NaN  1905
# 21            Charles K. Kao  Hong Kong  2009
# 267           Charles K. Kao        NaN  2009
# 286           Daniel C. Tsui        NaN  1998
# 253           Daniel C. Tsui        NaN  1998
# 252             Gao Xingjian        NaN  2000
# 203             Gao Xingjian     France  2000
# 9           Gerhard Herzberg        NaN  1971
# 279         Gerhard Herzberg     Canada  1971
# 275             John Polanyi     Canada  1986
# 48              John Polanyi    Hungary  1986
# 101             John Polanyi        NaN  1986
# 167          Karl von Frisch        NaN  1973
# 110          Karl von Frisch    Germany  1973
# 323     Luis Federico Leloir  Argentina  1970
# 189     Luis Federico Leloir        NaN  1970
# 160              Marie Curie     France  1903
# 143              Marie Curie     France  1911
# 217      Niels Ryberg Finsen        NaN  1903
# 228      Niels Ryberg Finsen    Denmark  1903
# 74                Otto Loewi        NaN  1936
# 192               Otto Loewi    Austria  1936
# 247           Peter Grünberg        NaN  2007
# 124           Peter Grünberg    Germany  2007
# 245  Richard Adolf Zsigmondy    Austria  1925
# 54   Richard Adolf Zsigmondy    Hungary  1925
# 73              Richard Kuhn    Germany  1938
# 191             Richard Kuhn        NaN  1938
# 259          Vladimir Prelog        NaN  1975
# 307          Vladimir Prelog        NaN  1975

# %%
df[df.name.str.contains('Marie')]
# Out:
#                                              link             name  year  \
# 143      http://en.wikipedia.org/wiki/Marie_Curie      Marie Curie  1911
# 160      http://en.wikipedia.org/wiki/Marie_Curie      Marie Curie  1903
# 210  http://en.wikipedia.org/wiki/Jean-Marie_Lehn  Jean-Marie Lehn  1987
#
#       category country born_in  \
# 143  Chemistry  France     NaN
# 160    Physics  France     NaN
# 210  Chemistry  France     NaN
#
#                                                   text      date_of_birth  \
# 143  Marie Curie ,  born in partitioned Poland (Rus...    7 November 1867
# 160  Marie Curie ,  born in partitioned Poland (Rus...    7 November 1867
# 210                  Jean-Marie Lehn , Chemistry, 1987  30 September 1939
#
#     date_of_death place_of_birth place_of_death  gender
# 143   4 July 1934         Warsaw    Sancellemoz  female
# 160   4 July 1934         Warsaw    Sancellemoz  female
# 210           NaN        Rosheim            NaN    male

# %%
df[df.name == 'Sidney Altman']
# Out:
#                                            link           name  year  \
# 274  http://en.wikipedia.org/wiki/Sidney_Altman  Sidney Altman  1989
#
#       category country born_in                              text  \
# 274  Chemistry     NaN  Canada  Sidney Altman *, Chemistry, 1989
#
#     date_of_birth date_of_death place_of_birth place_of_death gender
# 274    7 May 1939           NaN       Montreal            NaN   male

# %% [markdown]
# ### Dealing with Missing Fields

# %%
df[df.category.isnull()][['name', 'text']]
# Out:
# Empty DataFrame
# Columns: [name, text]
# Index: []

# %%
df[df.gender.isnull()]['name']
# Out:
# 165                  International Atomic Energy Agency
# 205                            Médecins Sans Frontières
# 269    Pugwash Conferences on Science and World Affairs
# 303                                        Grameen Bank
# 305                     Institut de Droit International
# Name: name, dtype: object

# %%
df.count()
# Out:
# link              326
# name              326
# year              326
# category          326
# country           261
# born_in            65
# text              326
# date_of_birth     321
# date_of_death     240
# place_of_birth    321
# place_of_death    240
# gender            321
# dtype: int64

# %%
df = df[df.gender.notnull()]

# %%
df.count()
# Out:
# link              321
# name              321
# year              321
# category          321
# country           256
# born_in            65
# text              321
# date_of_birth     321
# date_of_death     240
# place_of_birth    321
# place_of_death    240
# gender            321
# dtype: int64

# %% [markdown]
# ### Dealing with Times and Dates

# %%
df[['name', 'date_of_birth']]
# Out:
#                       name     date_of_birth
# 0         Karl Landsteiner      14 June 1868
# 1         Elfriede Jelinek   20 October 1946
# 2              Eric Kandel   7 November 1929
# 3              Walter Kohn      9 March 1923
# 4          Friedrich Hayek        8 May 1899
# ..                     ...               ...
# 321     Bertha von Suttner       9 June 1843
# 322  Adolfo Pérez Esquivel  26 November 1931
# 323   Luis Federico Leloir  6 September 1906
# 324       Bernardo Houssay     10 April 1887
# 325  Carlos Saavedra Lamas   1 November 1878
#
# [321 rows x 2 columns]

# %%
pd.to_datetime(df.date_of_birth, errors='raise')
# Out:
# 0     1868-06-14
# 1     1946-10-20
# 2     1929-11-07
# 3     1923-03-09
# 4     1899-05-08
#          ...
# 321   1843-06-09
# 322   1931-11-26
# 323   1906-09-06
# 324   1887-04-10
# 325   1878-11-01
# Name: date_of_birth, Length: 321, dtype: datetime64[ns]

# %%
with_death_dates = df[df.date_of_death.notnull()]
bad_dates = pd.isnull(pd.to_datetime(
            with_death_dates.date_of_death, errors='coerce'))

# %%
with_death_dates[bad_dates][['category', 'date_of_death']]
# Out:
# Empty DataFrame
# Columns: [category, date_of_death]
# Index: []

# %%
# df.date_of_death = pd.to_datetime(df.date_of_death, errors='coerce')

# %%
df['dob'] = pd.to_datetime(df.date_of_birth, errors='raise')

# %%
df['award_age'] = df.year - pd.DatetimeIndex(df.dob).year

# %%
df.sort_values('award_age').iloc[:10][['name', 'award_age', 'category', 'year', 'date_of_birth', 'dob', 'date_of_death']]
# Out:
#                         name  award_age                category  year  \
# 220            Ragnar Granit        -91  Physiology or Medicine  1809
# 221  Artturi Ilmari Virtanen        -86               Chemistry  1809
# 222    Frans Eemil Sillanpää        -79              Literature  1809
# 122   William Lawrence Bragg         25                 Physics  1915
# 56    Werner Karl Heisenberg         31                 Physics  1932
# 262            Tsung-Dao Lee         31                 Physics  1957
# 89          Rudolf Mössbauer         32                 Physics  1961
# 283     Frederick G. Banting         32  Physiology or Medicine  1923
# 18          Rigoberta Menchú         33                   Peace  1992
# 172    Frédéric Joliot-Curie         35               Chemistry  1935
#
#          date_of_birth        dob      date_of_death
# 220    30 October 1900 1900-10-30      12 March 1991
# 221    15 January 1895 1895-01-15   11 November 1973
# 222  16 September 1888 1888-09-16        3 June 1964
# 122      31 March 1890 1890-03-31        1 July 1971
# 56     5 December 1901 1901-12-05    1 February 1976
# 262   24 November 1926 1926-11-24                NaN
# 89     31 January 1929 1929-01-31  14 September 2011
# 283   14 November 1891 1891-11-14   21 February 1941
# 18      9 January 1959 1959-01-09                NaN
# 172      19 March 1900 1900-03-19     14 August 1958

# %%
df[['name', 'award_age', 'category', 'year', 'date_of_birth', 'dob', 'date_of_death']]
# Out:
#                       name  award_age                category  year  \
# 0         Karl Landsteiner         62  Physiology or Medicine  1930
# 1         Elfriede Jelinek         58              Literature  2004
# 2              Eric Kandel         71  Physiology or Medicine  2000
# 3              Walter Kohn         75               Chemistry  1998
# 4          Friedrich Hayek         75               Economics  1974
# ..                     ...        ...                     ...   ...
# 321     Bertha von Suttner         62                   Peace  1905
# 322  Adolfo Pérez Esquivel         49                   Peace  1980
# 323   Luis Federico Leloir         64               Chemistry  1970
# 324       Bernardo Houssay         60  Physiology or Medicine  1947
# 325  Carlos Saavedra Lamas         58                   Peace  1936
#
#         date_of_birth        dob      date_of_death
# 0        14 June 1868 1868-06-14       26 June 1943
# 1     20 October 1946 1946-10-20                NaN
# 2     7 November 1929 1929-11-07                NaN
# 3        9 March 1923 1923-03-09      19 April 2016
# 4          8 May 1899 1899-05-08      23 March 1992
# ..                ...        ...                ...
# 321       9 June 1843 1843-06-09       21 June 1914
# 322  26 November 1931 1931-11-26                NaN
# 323  6 September 1906 1906-09-06    2 December 1987
# 324     10 April 1887 1887-04-10  21 September 1971
# 325   1 November 1878 1878-11-01         5 May 1959
#
# [321 rows x 7 columns]

# %%
df.to_json('cleaned_nobel.json')

# %%
df.columns
# Out:
# Index(['link', 'name', 'year', 'category', 'country', 'born_in', 'text',
#        'date_of_birth', 'date_of_death', 'place_of_birth', 'place_of_death',
#        'gender', 'dob', 'award_age'],
#       dtype='object')
