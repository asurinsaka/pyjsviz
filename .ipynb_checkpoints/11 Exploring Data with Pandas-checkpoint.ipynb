# %% [markdown]
# # Starting to Explore

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import seaborn as sns

plt.rcParams['figure.figsize'] = 8, 4

# %%
df = pd.read_json('cleaned_nobel.json')

# %%
df.country.unique()
# Out:
# array(['Austria', 'Australia', 'Germany', 'Guatemala', 'Greece',
#        'Hong Kong', 'Hungary', 'Ghana', 'France', 'Finland', 'Denmark',
#        'East Timor', 'Egypt', 'Czech Republic',
#        "China, People's Republic of", 'Colombia',
#        'Congo, Democratic Republic', 'Costa Rica', 'China, Republic of',
#        'Chile', 'Canada', 'Belgium', 'Bangladesh', 'Belarus', 'Argentina'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 256 entries, 0 to 325
# Data columns (total 13 columns):
# link              256 non-null object
# name              256 non-null object
# year              256 non-null int64
# category          256 non-null object
# country           256 non-null object
# text              256 non-null object
# date_of_birth     256 non-null object
# date_of_death     192 non-null float64
# place_of_birth    256 non-null object
# place_of_death    192 non-null object
# gender            256 non-null object
# dob               256 non-null int64
# award_age         256 non-null int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 28.0+ KB

# %%
df.date_of_death = pd.to_datetime(df.date_of_death)
df.date_of_birth = pd.to_datetime(df.date_of_birth)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 256 entries, 0 to 325
# Data columns (total 13 columns):
# link              256 non-null object
# name              256 non-null object
# year              256 non-null int64
# category          256 non-null object
# country           256 non-null object
# text              256 non-null object
# date_of_birth     256 non-null datetime64[ns]
# date_of_death     192 non-null datetime64[ns]
# place_of_birth    256 non-null object
# place_of_death    192 non-null object
# gender            256 non-null object
# dob               256 non-null int64
# award_age         256 non-null int64
# dtypes: datetime64[ns](2), int64(3), object(8)
# memory usage: 28.0+ KB

# %% [markdown]
# # Plotting with Pandas

# %%
by_gender = df.groupby('gender')
by_gender.size().plot(kind='bar')

# %%
by_gender.size()
# Out:
# gender
# female     14
# male      242
# dtype: int64

# %% [markdown]
# # Gender Disparities

# %%
by_cat_gen = df.groupby(['category', 'gender'])
by_cat_gen.get_group(('Physics', 'female'))[['name', 'year']]
# Out:
#                  name  year
# 160       Marie Curie  1903
# 310  Donna Strickland  2018

# %%
by_cat_gen.size()
# Out:
# category                gender
# Chemistry               female     2
#                         male      54
# Economics               male       8
# Literature              female     5
#                         male      38
# Peace                   female     2
#                         male      33
# Physics                 female     2
#                         male      54
# Physiology or Medicine  female     3
#                         male      55
# dtype: int64

# %%
by_cat_gen.size().plot(kind='barh')

# %% [markdown]
# ### Unstacking Groups

# %%
by_cat_gen.size().unstack()
# Out:
# gender                  female  male
# category
# Chemistry                  2.0  54.0
# Economics                  NaN   8.0
# Literature                 5.0  38.0
# Peace                      2.0  33.0
# Physics                    2.0  54.0
# Physiology or Medicine     3.0  55.0

# %%
by_cat_gen.size().unstack().plot(kind='barh')

# %%
# 11-3
cat_gen_sz = by_cat_gen.size().unstack()
cat_gen_sz['total'] = cat_gen_sz.sum(axis=1)
cat_gen_sz = cat_gen_sz.sort_values(by='female', ascending=True)
cat_gen_sz[['female', 'total', 'male']].plot(kind='barh')

# %% [markdown]
# ### Historical Trends

# %%
by_year_gender = df.groupby(['year', 'gender'])
year_gen_sz = by_year_gender.size().unstack()
year_gen_sz.plot(kind='bar', figsize=(16, 4))

# %%
# 11-4
def thin_xticks(ax, tick_gap=10, rotation=45):
    """ Thin x-ticks and adjust rotation """
    ticks = ax.xaxis.get_ticklocs()
    ticklabels = [l.get_text() for l in ax.xaxis.get_ticklabels()]
    ax.xaxis.set_ticks(ticks[::tick_gap])
    ax.xaxis.set_ticklabels(ticklabels[::tick_gap],
                            rotation=rotation)
    ax.figure.show()

# %%
by_year_gender = df.groupby(['year', 'gender'])
by_year_gender.size().unstack()
# Out:
# gender  female  male
# year
# 1809       NaN   3.0
# 1901       NaN   5.0
# 1902       NaN   2.0
# 1903       1.0   3.0
# 1904       NaN   1.0
# ...        ...   ...
# 2014       NaN   3.0
# 2015       2.0   1.0
# 2016       NaN   3.0
# 2017       NaN   1.0
# 2018       1.0   2.0
#
# [105 rows x 2 columns]

# %%
new_index = pd.Index(np.arange(1901, 2015), name='year')
by_year_gender = df.groupby(['year', 'gender'])
year_gen_sz = by_year_gender.size().unstack().reindex(new_index)

# %%
# 11-5

new_index = pd.Index(np.arange(1901, 2015), name='year')
by_year_gender = df.groupby(['year', 'gender'])
year_gen_sz = by_year_gender.size().unstack().reindex(new_index)

fig, axes = plt.subplots(nrows=2, ncols=1,
                         sharex=True, sharey=True)

ax_f = axes[0]
ax_m = axes[1]

fig.suptitle('Nobel Prize-winners by gender', fontsize=16)

ax_f.bar(year_gen_sz.index, year_gen_sz.female)
ax_f.set_ylabel('Female winners')

ax_m.bar(year_gen_sz.index, year_gen_sz.male)
ax_m.set_ylabel('Maile winners')

ax_m.set_xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# # National Trends

# %%
df.groupby('country').size().sort_values(ascending=False).plot(kind='bar', figsize=(12, 4))

# %% [markdown]
# ## Prize Winner per Capita

# %%
nat_group = df.groupby('country')
ngsz = nat_group.size()
ngsz.index
# Out:
# Index(['Argentina', 'Australia', 'Austria', 'Bangladesh', 'Belarus', 'Belgium',
#        'Canada', 'Chile', 'China, People's Republic of', 'China, Republic of',
#        'Colombia', 'Congo, Democratic Republic', 'Costa Rica',
#        'Czech Republic', 'Denmark', 'East Timor', 'Egypt', 'Finland', 'France',
#        'Germany', 'Ghana', 'Greece', 'Guatemala', 'Hong Kong', 'Hungary'],
#       dtype='object', name='country')

# %%
from pymongo import MongoClient

def get_mongo_database(db_name, host='10.0.0.153',
                       port=27017, username=None, password=None):
    """ Get named database from MongoDB with/out authentication """
    if username and password:
        mongo_url = f'mongodb://{username}:{password}@{host}/{db_name}'
        conn = MongoClient(mongo_url)
    else:
        conn = MongoClient(host, port)
        
    return conn[db_name]

# %%
def mongo_to_dataframe(db_name, collection, query={},
                       host="10.0.0.153", port=27017,
                       username=None, password=None,
                       no_id=True):
    """ create a dataframe from mongodb collection """
    db = get_mongo_database(db_name, host, port, username, password)
    
    cursor = db[collection].find(query)
    
    df = pd.DataFrame(list(cursor))
    
    if no_id:
        del df['_id']
    
    return df

# %%
df_countries = mongo_to_dataframe('nobel_prize', 'country_data')
df_countries.iloc[0]
# Out:
# name                                                    Afghanistan
# topLevelDomain                                                [.af]
# alpha2Code                                                       AF
# alpha3Code                                                      AFG
# callingCodes                                                   [93]
# capital                                                       Kabul
# altSpellings                                       [AF, Afġānistān]
# region                                                         Asia
# subregion                                             Southern Asia
# population                                                 26023100
# latlng                                                 [33.0, 65.0]
# demonym                                                      Afghan
# area                                                         652230
# gini                                                           27.8
# timezones                                               [UTC+04:30]
# borders                              [IRN, PAK, TKM, UZB, TJK, CHN]
# nativeName                                                افغانستان
# numericCode                                                     004
# currencies                                                    [AFN]
# languages                                              [ps, uz, tk]
# translations      {'de': 'Afghanistan', 'es': 'Afganistán', 'fr'...
# relevance                                                         0
# Name: 0, dtype: object

# %%
df_countries = df_countries.set_index('name')
df_countries['nobel_wins'] = ngsz
df_countries['nobel_wins_per_capita'] = df_countries.nobel_wins / df_countries.population

# %%
df_countries.sort_values(by='nobel_wins_per_capita',
                         ascending=False).nobel_wins_per_capita[df_countries.nobel_wins.notnull()].plot(kind='bar')

# %%
df_countries.nobel_wins.notnull()
# Out:
# name
# Afghanistan          False
# Åland Islands        False
# Albania              False
# Algeria              False
# American Samoa       False
#                      ...
# Wallis and Futuna    False
# Western Sahara       False
# Yemen                False
# Zambia               False
# Zimbabwe             False
# Name: nobel_wins, Length: 250, dtype: bool

# %%
df_countries[df_countries.nobel_wins > 2].sort_values(
    by='nobel_wins_per_capita', ascending=False).nobel_wins_per_capita.plot(kind='bar')

# %% [markdown]
# ### Prizes by Category

# %%
nat_cat_sz = df.groupby(['country', 'category']).size().unstack()
nat_cat_sz
# Out:
# category                     Chemistry  Economics  Literature  Peace  Physics  \
# country
# Argentina                          1.0        NaN         NaN    2.0      NaN
# Australia                          NaN        NaN         1.0    NaN      2.0
# Austria                            3.0        1.0         1.0    2.0      3.0
# Bangladesh                         NaN        NaN         NaN    1.0      NaN
# Belarus                            NaN        NaN         1.0    NaN      NaN
# Belgium                            1.0        NaN         1.0    3.0      1.0
# Canada                             4.0        1.0         1.0    1.0      4.0
# Chile                              NaN        NaN         2.0    NaN      NaN
# China, People's Republic of        NaN        NaN         1.0    1.0      NaN
# China, Republic of                 NaN        NaN         NaN    NaN      2.0
# Colombia                           NaN        NaN         1.0    1.0      NaN
# Congo, Democratic Republic         NaN        NaN         NaN    1.0      NaN
# Costa Rica                         NaN        NaN         NaN    1.0      NaN
# Czech Republic                     1.0        NaN         1.0    NaN      NaN
# Denmark                            1.0        NaN         3.0    1.0      3.0
# East Timor                         NaN        NaN         NaN    2.0      NaN
# Egypt                              1.0        NaN         1.0    2.0      NaN
# Finland                            1.0        1.0         1.0    1.0      NaN
# France                             9.0        3.0        16.0   10.0     14.0
# Germany                           30.0        1.0         8.0    4.0     24.0
# Ghana                              NaN        NaN         NaN    1.0      NaN
# Greece                             NaN        NaN         2.0    NaN      NaN
# Guatemala                          NaN        NaN         1.0    1.0      NaN
# Hong Kong                          NaN        NaN         NaN    NaN      1.0
# Hungary                            4.0        1.0         1.0    NaN      2.0
#
# category                     Physiology or Medicine
# country
# Argentina                                       1.0
# Australia                                       7.0
# Austria                                         5.0
# Bangladesh                                      NaN
# Belarus                                         NaN
# Belgium                                         4.0
# Canada                                          4.0
# Chile                                           NaN
# China, People's Republic of                     1.0
# China, Republic of                              NaN
# Colombia                                        NaN
# Congo, Democratic Republic                      NaN
# Costa Rica                                      NaN
# Czech Republic                                  NaN
# Denmark                                         5.0
# East Timor                                      NaN
# Egypt                                           NaN
# Finland                                         1.0
# France                                         12.0
# Germany                                        16.0
# Ghana                                           NaN
# Greece                                          NaN
# Guatemala                                       NaN
# Hong Kong                                       NaN
# Hungary                                         2.0

# %%
COL_NUM = 2
ROW_NUM = 3

fig, axes = plt.subplots(ROW_NUM, COL_NUM, figsize=(12, 12))

for i, (label, col) in enumerate(nat_cat_sz.iteritems()):
    ax = axes[i//COL_NUM, i%COL_NUM]
    col = col.sort_values(ascending=False)[:10]
    col.plot(kind='barh', ax=ax)
    ax.set_title(label)
    
plt.tight_layout()

# %% [markdown]
# ## Historical Trends in Prize Distribution

# %%
plt.rcParams['font.size'] = 20

# %%
new_index = pd.Index(np.arange(1901, 2015), name='year')

by_year_nat_sz = df.groupby(['year', 'country']).size().unstack().reindex(new_index)

# %%
by_year_nat_sz['Germany'].cumsum().plot()

# %%
by_year_nat_sz['Germany'].fillna(0).cumsum().plot()

# %%
by_year_nat_sz = df.groupby(['year', 'country']).size().unstack().reindex(new_index).fillna(0)

not_Germany = by_year_nat_sz.columns.tolist()
not_Germany.remove('Germany')

by_year_nat_sz['Not Germany'] = by_year_nat_sz[not_Germany].sum(axis=1)
ax = by_year_nat_sz[['Germany', 'Not Germany']].cumsum().plot()

# %%
by_year_nat_sz = df.groupby(['year', 'country']).size().unstack().reindex(new_index).fillna(0)
by_year_nat_sz.columns.sort_values()
# Out:
# Index(['Argentina', 'Australia', 'Austria', 'Bangladesh', 'Belarus', 'Belgium',
#        'Canada', 'Chile', 'China, People's Republic of', 'China, Republic of',
#        'Colombia', 'Congo, Democratic Republic', 'Costa Rica',
#        'Czech Republic', 'Denmark', 'East Timor', 'Egypt', 'Finland', 'France',
#        'Germany', 'Ghana', 'Greece', 'Guatemala', 'Hong Kong', 'Hungary'],
#       dtype='object', name='country')

# %%
regions = [
    {
        'label': 'N. America',
        'countries': ['Canada']
     },
    {
        'label': 'Europe',
        'countries': ['Germany', 'France']
    },
    {
        'label': 'Asia',
        'countries': ['Bangladesh', 'China, People\'s Republic of', 'China, Republic of', 'Hong Kong']
    }
]

# %%
for region in regions:
    by_year_nat_sz[region['label']] = by_year_nat_sz[region['countries']].sum(axis=1)
    
by_year_nat_sz[[r['label'] for r in regions]].cumsum().plot()

# %%
plt.rcParams.update({'font.size': 16})

# %%
COL_NUM = 4
ROW_NUM = 4

by_nat_sz = df.groupby('country').size()
by_nat_sz.sort_values(ascending=False, inplace=True)

fig, axes = plt.subplots(COL_NUM, ROW_NUM,
                         sharex=True, sharey=True,
                         figsize=(12, 12))

for i, nat in enumerate(by_nat_sz.index[1:17]):
    ax = axes[i//COL_NUM, i%COL_NUM]
    by_year_nat_sz[nat].cumsum().plot(ax=ax)
    ax.set_title(nat)

# %%
sns.set()
cmap = sns.cm.rocket_r

# %%
bins = np.arange(df.year.min(), df.year.max(), 10)

by_year_nat_binned = df.groupby(
    [pd.cut(df.year, bins, precision=0), 'country']
).size().unstack().fillna(0)

plt.figure(figsize=(8, 8))

sns.heatmap(
    by_year_nat_binned[by_year_nat_binned.sum(axis=1) > 2].transpose(), cmap=cmap)

# %% [markdown]
# by_year_nat_binned.sum(axis=1)

# %%
by_year_nat_binned.transpose()
# Out:
# year                (1899, 1909]  (1909, 1919]  (1919, 1929]  (1929, 1939]  \
# country
# Austria                      1.0           2.0           3.0           4.0
# Belgium                      1.0           3.0           0.0           1.0
# Canada                       1.0           0.0           2.0           0.0
# Denmark                      2.0           2.0           3.0           0.0
# France                      12.0           6.0           8.0           4.0
# Germany                     12.0          10.0          10.0          10.0
# Australia                    0.0           1.0           0.0           0.0
# Hungary                      0.0           0.0           1.0           1.0
# Argentina                    0.0           0.0           0.0           1.0
# Chile                        0.0           0.0           0.0           0.0
# China, Republic of           0.0           0.0           0.0           0.0
# Czech Republic               0.0           0.0           0.0           0.0
# Greece                       0.0           0.0           0.0           0.0
# Guatemala                    0.0           0.0           0.0           0.0
# Egypt                        0.0           0.0           0.0           0.0
# Colombia                     0.0           0.0           0.0           0.0
# Costa Rica                   0.0           0.0           0.0           0.0
# East Timor                   0.0           0.0           0.0           0.0
# Bangladesh                   0.0           0.0           0.0           0.0
# Finland                      0.0           0.0           0.0           0.0
# Ghana                        0.0           0.0           0.0           0.0
# Hong Kong                    0.0           0.0           0.0           0.0
#
# year                (1939, 1949]  (1949, 1959]  (1959, 1969]  (1969, 1979]  \
# country
# Austria                      1.0           0.0           1.0           2.0
# Belgium                      0.0           1.0           0.0           3.0
# Canada                       0.0           1.0           0.0           1.0
# Denmark                      2.0           0.0           0.0           2.0
# France                       1.0           5.0           7.0           1.0
# Germany                      1.0           5.0           5.0           5.0
# Australia                    1.0           0.0           2.0           1.0
# Hungary                      1.0           0.0           2.0           1.0
# Argentina                    1.0           0.0           0.0           1.0
# Chile                        1.0           0.0           0.0           1.0
# China, Republic of           0.0           2.0           0.0           0.0
# Czech Republic               0.0           1.0           0.0           0.0
# Greece                       0.0           0.0           1.0           1.0
# Guatemala                    0.0           0.0           1.0           0.0
# Egypt                        0.0           0.0           0.0           1.0
# Colombia                     0.0           0.0           0.0           0.0
# Costa Rica                   0.0           0.0           0.0           0.0
# East Timor                   0.0           0.0           0.0           0.0
# Bangladesh                   0.0           0.0           0.0           0.0
# Finland                      0.0           0.0           0.0           0.0
# Ghana                        0.0           0.0           0.0           0.0
# Hong Kong                    0.0           0.0           0.0           0.0
#
# year                (1979, 1989]  (1989, 1999]  (1999, 2009]
# country
# Austria                      0.0           0.0           1.0
# Belgium                      0.0           0.0           0.0
# Canada                       1.0           4.0           1.0
# Denmark                      1.0           1.0           0.0
# France                       5.0           3.0           6.0
# Germany                      8.0           7.0           7.0
# Australia                    0.0           2.0           2.0
# Hungary                      1.0           2.0           1.0
# Argentina                    1.0           0.0           0.0
# Chile                        0.0           0.0           0.0
# China, Republic of           0.0           0.0           0.0
# Czech Republic               1.0           0.0           0.0
# Greece                       0.0           0.0           0.0
# Guatemala                    0.0           1.0           0.0
# Egypt                        1.0           1.0           1.0
# Colombia                     1.0           0.0           0.0
# Costa Rica                   1.0           0.0           0.0
# East Timor                   0.0           2.0           0.0
# Bangladesh                   0.0           0.0           1.0
# Finland                      0.0           0.0           1.0
# Ghana                        0.0           0.0           1.0
# Hong Kong                    0.0           0.0           1.0
